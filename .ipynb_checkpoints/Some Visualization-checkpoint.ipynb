# %%
# %store -r data
# %store -r encoders

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import plotly 
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs as go
import plotly.plotly as py
init_notebook_mode(connected=True)
plotly.tools.set_credentials_file(username='lyndongreenhouse', api_key='2OB7yoHDZgz8GxKxC9y4')
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
data["duration"] = pd.to_timedelta(data["deadline"]  - data['launched'])

# %%
success_proj = data[data["state"] == True]
suc_cat = pd.DataFrame(success_proj.main_category.value_counts())
suc_cat.columns = ["suc_main_cat"]
suc_cat["total"] = data.main_category.value_counts()
suc_cat["rate"] = suc_cat.suc_main_cat / suc_cat.total * 100
suc_cat.index = encoders["main_category"].inverse_transform(suc_cat.index)
suc_cat.sort_values(by="rate",inplace=True)

# %%
gdata = [go.Bar(x = suc_cat.index, y = suc_cat.suc_main_cat, name = "Success Number"),
        go.Bar(x = suc_cat.index, y = suc_cat.total,name = "Total Number"),
        go.Scatter(x = suc_cat.index, y = suc_cat.rate,yaxis='y2', name = "Success Rate")
       ]

# %%
iplot(go.Figure(data = gdata, 
        layout = go.Layout(
            title='Main Catagory Successful Rate',
        yaxis=dict(
            title='Number of Projects'
        ),
        yaxis2=dict(
            title='Successful Rate',
            tickfont=dict(
                color='rgb(148, 103, 189)'
            ),
            overlaying='y',
            side='right'
        )
        )
     )
     )
# Out:
# <div id="e344e99a-8285-4e7e-861b-19444550e49f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e344e99a-8285-4e7e-861b-19444550e49f", [{"name": "Success Number", "x": ["Technology", "Journalism", "Crafts", "Fashion", "Food", "Photography", "Publishing", "Design", "Games", "Film & Video", "Art", "Music", "Comics", "Theater", "Dance"], "y": [6434, 1012, 2115, 5593, 6085, 3305, 12300, 10550, 12518, 23623, 11510, 24197, 5842, 6534, 2338], "type": "bar", "uid": "b5bd1965-7e53-4c85-93cf-145fda430d30"}, {"name": "Total Number", "x": ["Technology", "Journalism", "Crafts", "Fashion", "Food", "Photography", "Publishing", "Design", "Games", "Film & Video", "Art", "Music", "Comics", "Theater", "Dance"], "y": [32192, 4724, 8733, 22566, 24418, 10731, 39575, 29765, 34944, 63253, 27959, 51637, 10743, 10872, 3750], "type": "bar", "uid": "53eb4aa7-0c41-43b8-871f-fc68a88d2320"}, {"name": "Success Rate", "x": ["Technology", "Journalism", "Crafts", "Fashion", "Food", "Photography", "Publishing", "Design", "Games", "Film & Video", "Art", "Music", "Comics", "Theater", "Dance"], "y": [19.98633200795229, 21.422523285351396, 24.218481621435934, 24.785074891429584, 24.920140879678925, 30.798620818190294, 31.080227416298168, 35.4443137913657, 35.82303113553114, 37.34684520892289, 41.16742372760113, 46.85980982628735, 54.379596016010424, 60.099337748344375, 62.346666666666664], "yaxis": "y2", "type": "scatter", "uid": "efabecfb-89f1-4eb7-9332-86daf4e65432"}], {"title": "Main Catagory Successful Rate", "yaxis": {"title": "Number of Projects"}, "yaxis2": {"overlaying": "y", "side": "right", "tickfont": {"color": "rgb(148, 103, 189)"}, "title": "Successful Rate"}}, {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("e344e99a-8285-4e7e-861b-19444550e49f"));});</script>

# %%
success_proj = data[data["state"] == True]
suc_sub_cat = pd.DataFrame(success_proj.category.value_counts())
suc_sub_cat.columns = ["suc_cat"]
suc_sub_cat["total"] = data.category.value_counts()
suc_sub_cat["rate"] = suc_sub_cat.suc_cat / suc_sub_cat.total * 100
suc_sub_cat.index = encoders["category"].inverse_transform(suc_sub_cat.index)
suc_sub_cat.sort_values(by="rate",inplace=True)

gdata = [go.Bar(x = suc_sub_cat.index, y = suc_sub_cat.suc_cat, name = "Success Number"),
        go.Bar(x = suc_sub_cat.index, y = suc_sub_cat.total,name = "Total Number"),
        go.Scatter(x = suc_sub_cat.index, y = suc_sub_cat.rate,yaxis='y2', name = "Success Rate")
       ]

iplot(go.Figure(data = gdata, 
        layout = go.Layout(
            title='Sub Catagory Successful Rate',
        yaxis=dict(
            title='Number of Projects'
        ),
        yaxis2=dict(
            title='Successful Rate',
            tickfont=dict(
                color='rgb(148, 103, 189)'
            ),
            overlaying='y',
            side='right'
        )
        )
     )
     )
# Out:
# <div id="6d2ed207-0138-4a00-9615-d0eb1b1f9e92" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("6d2ed207-0138-4a00-9615-d0eb1b1f9e92", [{"name": "Success Number", "x": ["Apps", "Mobile Games", "Web", "Video", "Software", "Food Trucks", "Candles", "Action", "Television", "Hip-Hop", "Couture", "DIY", "Places", "Restaurants", "Photo", "Farmer's Markets", "Embroidery", "Ready-to-wear", "Live Games", "Bacon", "Nature", "Flight", "Technology", "Events", "Childrenswear", "Family", "Apparel", "Interactive Design", "Video Games", "Printing", "Academic", "People", "Farms", "Young Adult", "Crochet", "Print", "Community Gardens", "Movie Theaters", "Gaming Hardware", "Quilts", "R&B", "Translations", "Architecture", "Games", "Cookbooks", "Fiction", "Jewelry", "Drinks", "Animals", "Crafts", "Woodworking", "Fashion", "Video Art", "Pet Fashion", "Fabrication Tools", "Nonfiction", "Animation", "Journalism", "Thrillers", "Audio", "Publishing", "Glass", "Digital Art", "Textiles", "Gadgets", "Latin", "Food", "Romance", "Weaving", "Webseries", "Film & Video", "Small Batch", "Fantasy", "Horror", "Workshops", "Vegan", "Wearables", "Makerspaces", "Footwear", "Electronic Music", "Photography", "Hardware", "Design", "Music Videos", "Accessories", "Mixed Media", "Children's Books", "Painting", "Spaces", "Stationery", "Poetry", "Conceptual Art", "3D Printing", "Product Design", "Civic Design", "Documentary", "Fine Art", "Science Fiction", "Space Exploration", "Graphic Design", "Drama", "Taxidermy", "Puzzles", "Sculpture", "Metal", "Narrative Film", "Experimental", "Playing Cards", "Robots", "Calendars", "Comedy", "Photobooks", "Periodicals", "Music", "Art", "Sound", "Faith", "Radio & Podcasts", "Performance Art", "Ceramics", "Blues", "World Music", "Kids", "Pottery", "Camera Equipment", "Punk", "DIY Electronics", "Zines", "Pop", "Knitting", "Literary Journals", "Installations", "Public Art", "Comics", "Musical", "Art Books", "Immersive", "Illustration", "Rock", "Shorts", "Festivals", "Graphic Novels", "Webcomics", "Tabletop Games", "Literary Spaces", "Plays", "Typography", "Comic Books", "Jazz", "Performances", "Theater", "Classical Music", "Country & Folk", "Indie Rock", "Letterpress", "Dance", "Anthologies", "Residencies", "Chiptune"], "y": [378, 153, 443, 51, 371, 217, 55, 107, 156, 602, 42, 183, 118, 457, 32, 70, 19, 145, 180, 38, 100, 76, 1317, 158, 95, 66, 1414, 79, 2386, 49, 188, 230, 242, 172, 35, 161, 66, 52, 99, 19, 107, 35, 179, 779, 130, 2233, 301, 594, 63, 1162, 292, 2188, 51, 37, 66, 2230, 682, 472, 200, 111, 1640, 38, 371, 77, 827, 38, 3297, 55, 27, 1698, 3070, 557, 106, 397, 50, 185, 388, 76, 298, 700, 1876, 1206, 1413, 240, 1073, 945, 2348, 1149, 295, 77, 487, 366, 242, 7962, 104, 5924, 283, 272, 120, 750, 812, 5, 88, 698, 275, 2013, 358, 967, 226, 128, 912, 635, 515, 6432, 3385, 274, 456, 394, 934, 132, 117, 922, 126, 44, 192, 146, 417, 179, 1561, 85, 133, 233, 1543, 2506, 462, 1356, 169, 1626, 3500, 6673, 457, 1011, 358, 7866, 13, 804, 63, 1614, 1104, 624, 4405, 1647, 2812, 3618, 31, 1542, 521, 50, 27], "type": "bar", "uid": "7c21f221-1c2d-4a20-9d9d-7b3d5bbd15fa"}, {"name": "Total Number", "x": ["Apps", "Mobile Games", "Web", "Video", "Software", "Food Trucks", "Candles", "Action", "Television", "Hip-Hop", "Couture", "DIY", "Places", "Restaurants", "Photo", "Farmer's Markets", "Embroidery", "Ready-to-wear", "Live Games", "Bacon", "Nature", "Flight", "Technology", "Events", "Childrenswear", "Family", "Apparel", "Interactive Design", "Video Games", "Printing", "Academic", "People", "Farms", "Young Adult", "Crochet", "Print", "Community Gardens", "Movie Theaters", "Gaming Hardware", "Quilts", "R&B", "Translations", "Architecture", "Games", "Cookbooks", "Fiction", "Jewelry", "Drinks", "Animals", "Crafts", "Woodworking", "Fashion", "Video Art", "Pet Fashion ...

# %%
data.head(2)
# Out:
#                                                      name  category  \
# ID
# 1000002330                The Songs of Adelaide & Abullah       108
# 1000003930  Greeting From Earth: ZGAC Arts Capsule For ET        93
#
#             main_category  currency   deadline     goal            launched  \
# ID
# 1000002330             12         5 2015-10-09   1000.0 2015-08-11 12:12:28
# 1000003930              6        13 2017-11-01  30000.0 2017-09-02 04:43:57
#
#             pledged  state  backers  country  usd pledged  usd_pledged_real  \
# ID
# 1000002330      0.0  False        0        9          0.0               0.0
# 1000003930   2421.0  False       15       22        100.0            2421.0
#
#             usd_goal_real         duration
# ID
# 1000002330        1533.95 58 days 11:47:32
# 1000003930       30000.00 59 days 19:16:03

# %%
data = dict(
    type='sankey',
    node = dict(
      pad = 15,
      thickness = 20,
      line = dict(
        color = "black",
        width = 0.5
      ),
      label = ["A1", "A2", "B1", "B2", "C1", "C2","D1"],
      color = ["blue", "blue", "blue", "blue", "blue", "blue"]
    ),
    link = dict(
      source = [0,1,0,2,3,3],
      target = [2,3,3,4,4,5],
      value = [8,4,2,8,4,2]
  ))

layout =  dict(
    title = "Basic Sankey Diagram",
    font = dict(
      size = 10
    )
)

fig = dict(data=[data], layout=layout)
iplot(fig, validate=False)
# Out:
# <div id="122403c5-751b-45e7-a527-12488a10ae80" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("122403c5-751b-45e7-a527-12488a10ae80", [{"type": "sankey", "node": {"pad": 15, "thickness": 20, "line": {"color": "black", "width": 0.5}, "label": ["A1", "A2", "B1", "B2", "C1", "C2", "D1"], "color": ["blue", "blue", "blue", "blue", "blue", "blue"]}, "link": {"source": [0, 1, 0, 2, 3, 3], "target": [2, 3, 3, 4, 4, 5], "value": [8, 4, 2, 8, 4, 2]}}], {"title": "Basic Sankey Diagram", "font": {"size": 10}}, {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("122403c5-751b-45e7-a527-12488a10ae80"));});</script>

# %%
#sub -> main catagory -> country -> duration -> goal   -> state

# %%
gsource = []
gtarget =  []
gvalue =  []
glabel =  []

# %%
data["duation_cat"] = pd.cut(data.duration, bins = 1000).astype(str)
data["goal_cat"] = pd.cut(data.goal, bins = 20).astype(str)

# %%
subcat = list(set(encoders["category"].inverse_transform(data.category)))
cat = list(set(encoders["main_category"].inverse_transform(data.main_category)))
for i in range(len(subcat)):
    if subcat[i] in cat:
        subcat[i] = subcat[i]+"_sub"
cou = list(set(encoders["country"].inverse_transform(data.country)))
dua = list(set(data.duation_cat))
goal = list(set(data.goal_cat))
total = subcat + cat+cou+dua+goal

# %%
#Sub -> Main
temp = sorted(list(set(zip(data.category,data.main_category))),key=lambda x: x[1])
value = [list(zip(data.category,data.main_category)).count(x) for x in temp]

# %%
gsource = [total.index(encoders["category"].inverse_transform([x[0]])[0]) for x in temp]
gtarget = [total.index(encoders["main_category"].inverse_transform([x[1]])[0]) for x in temp]
gvalue = value

# %%
data_trace = dict(
    type='sankey',
    node = dict(
      pad = 15,
      thickness = 15,
      line = dict(
        color = "black",
        width = 0.5
      ),
        label = total,
        color = ["blue"]*len(total)
    ),
    link = dict(
      source =  gsource,
      target =  gtarget,
      value =  gvalue
  )
)

layout =  go.Layout(
    title = "Test",
    font = dict(
      size = 10
    )
)

fig = go.Figure(data=[data_trace],layout = layout)
py.iplot(fig, validate=True)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~lyndongreenhouse/14.embed" height="525px" width="100%"></iframe>
